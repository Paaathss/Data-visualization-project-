# %% [markdown]
# **Loading Libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading Data**

# %%
# reading

df = pd.read_csv('/content/drive/MyDrive/project/indian_food.csv')
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
# no.of cols and rows

df.shape
# Out:
# (255, 9)

# %%
#to display first few rows

df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
print(f'columns available in the Datasets are:\n\n {df.columns}')
# Out:
# columns available in the Datasets are:
#
#  Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %%
# to see info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
# summary statistics

df.describe()
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
# to chech missing values

print(df.isnull().sum())
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
# to check duplicate rows
df.duplicated().any()
# Out:
# False

# %%
df.isna().any()
# Out:
# name              False
# ingredients       False
# diet              False
# prep_time         False
# cook_time         False
# flavor_profile    False
# course            False
# state             False
# region             True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
df.nunique()
# Out:
# name              255
# ingredients       252
# diet                2
# prep_time          22
# cook_time          19
# flavor_profile      5
# course              4
# state              25
# region              7
# dtype: int64

# %%
# to see a quick info of categorical data

df.describe(exclude = np.number)
# Out:
#               name              ingredients        diet flavor_profile  \
# count          255                      255         255            255
# unique         255                      252           2              5
# top     Balu shahi  Gram flour, ghee, sugar  vegetarian          spicy
# freq             1                        2         226            133
#
#              course    state region
# count           255      255    254
# unique            4       25      7
# top     main course  Gujarat   West
# freq            129       35     74

# %%
print(df[['diet', 'course']].describe())
# Out:
#               diet       course
# count          255          255
# unique           2            4
# top     vegetarian  main course
# freq           226          129

# %%
#first drop unnecessary columns

df = pd.read_csv('/content/drive/MyDrive/project/indian_food.csv')
df.drop(columns = ['prep_time','cook_time'])
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet flavor_profile   course            state      region
# ...

# %%
#check missing values

df.isna().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
df['name'].value_counts()
# Out:
# name
# Balu shahi         1
# Chorafali          1
# Vada               1
# Chicken Varuval    1
# Upma               1
#                   ..
# Kachori            1
# Kadai paneer       1
# Kadhi pakoda       1
# Karela bharta      1
# Pinaca             1
# Name: count, Length: 255, dtype: int64

# %% [markdown]
# **VISUALIZATION**

# %%
#Distribution of Preparation Time

import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/project/indian_food.csv')


plt.figure(figsize=(9,6))
sns.histplot(df['prep_time'], bins=23,kde=True)
plt.style.available

plt.grid(True,color='pink')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Frequency')
plt.title('Distribution of Preparation Time')
plt.style.use( 'dark_background')

plt.show()

# %% [markdown]
# **Diet Composition - Veg vs Non Veg**

# %%
plt.figure(figsize=(5, 4))

df['diet'].value_counts().plot(kind='bar',color=['beige', 'g'])
plt.xlabel('Diet')
plt.ylabel('Count')
plt.title('Vegetarian vs Non-vegetarian Dishes')

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Flavour Profile**

# %%
plt.figure(figsize=(8,5))
df['flavor_profile'].value_counts().plot(kind='bar', color=['pink', 'beige'],label = 'flavor')
plt.xlabel('Flavor Profile')
plt.ylabel('Count')
plt.title('DISTRIBUTION OF FLAVOR PROFILES')
plt.legend(loc='upper left')


plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# **Course Distribution**

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(8, 5))
df['course'].value_counts().plot(kind='pie',autopct = '%1.1f%%',shadow = 'True',explode = (0,0,0,1),colors=['beige', 'pink', 'lightblue', 'y'])
plt.title('Distribution of Meal Courses')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Feature relationships**

# %%
sns.scatterplot(x='prep_time', y='cook_time', data=df, color = 'pink')
plt.xlabel('Preparation Time (minutes)')
plt.ylabel('Cooking Time (minutes)')
plt.title('Preparation Time vs. Cooking Time')
plt.show()

# %% [markdown]
# Box plot

# %%
sns.boxplot(df['region'],color = 'y')
# Out:
# <Axes: ylabel='region'>

# %%
sns.boxplot(x = 'cook_time',y = 'flavor_profile',data = df,hue = 'diet')
# Out:
# <Axes: xlabel='cook_time', ylabel='flavor_profile'>

# %%
# Select only the numeric columns
numeric_columns = ['prep_time', 'cook_time']

# Compute the correlation matrix
corr_matrix = df[numeric_columns].corr()

# Create a heatmap
plt.figure(figsize=(7, 5))
sns.heatmap(corr_matrix, annot=True, cmap='pink', square=True)
plt.title('Correlation Heatmap for Numeric Features')
plt.show()

# %% [markdown]
# pair plot

# %%
sns.pairplot(df,hue = 'flavor_profile')

# %% [markdown]
# **State Wise cooking time**

# %%
plt.figure(figsize=(14, 10))
sns.boxplot(x='state', y='cook_time', data=df)
plt.xlabel('State')
plt.ylabel('Preparation Time (minutes)')
plt.title('Distribution of Preparation Times by State')
plt.xticks(rotation=45)
plt.show()

# %%
df.head(6)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
# ...

# %% [markdown]
# **SUMMARY ANALYSIS**

# %% [markdown]
# **Dataset Overview**
#
# _Data Loaded:_ The dataset consists of various attributes related to Indian dishes, including preparation time, cooking time, dietary preferences, flavor profiles, meal courses, and the states from which the dishes originate.

# %% [markdown]
# **KEY OBSERVATION**

# %% [markdown]
# 1. **Data Shape and Info:**
#
# The dataset has a specific number of rows and columns (not specified in the code output).
# The info method gives insights into the data types and presence of missing values.
#
# 2. **Preparation and Cooking Time:**
#
# _Descriptive Statistics:_ The prep time and cook time have been summarized, showcasing their central tendency and spread.
# _Distribution of Preparation Time:_
# A histogram with a KDE curve shows how prep times are distributed across the dataset.
#
# 3. **Dietary Preferences:**
#
# A bar plot illustrates the count of vegetarian vs. non-vegetarian dishes, helping to understand dietary trends in the dataset.
#
# 4. **Flavor Profiles:**
#
# A bar plot reveals the distribution of various flavor profiles, indicating the most and least common flavors in the dataset.
#
# 5. **Meal Courses:**
#
# A pie chart visualizes the distribution of meal courses, showing the proportion of different meal types (like appetizers, main courses, desserts, etc.).
#
# 6. **Preparation vs. Cooking Time:**
#
# A scatter plot compares preparation time to cooking time, which can highlight any trends or correlations between these two features.
#
# 7. **Correlation Analysis:**
#
# A heatmap shows the correlation between numeric features (prep time and cook time), giving insights into how these variables relate to each other.
#
# 8. **State-wise Distribution of Preparation Times:**
#
# A box plot illustrates how preparation times vary by state, indicating which states may have dishes that require more or less prep time.
